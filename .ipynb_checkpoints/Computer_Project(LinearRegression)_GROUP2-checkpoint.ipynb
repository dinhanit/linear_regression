# %%
from numpy import loadtxt
import tensorflow.compat.v1 as tf
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('data/train.csv',index_col = 0)

# %%
df_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# id
# 1               842     0          2.2         0   1       0           7
# 2              1021     1          0.5         1   0       1          53
# 3               563     1          0.5         1   2       1          41
# 4               615     1          2.5         0   0       0          10
# 5              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1496           1472     0          3.0         0   4       1          20
# 1497           1868     1          0.5         0   2       1          40
# 1498           1375     0          2.9         0   2       0          20
# 1499            881     0          1.0         0   1       0          64
# 1500           1742     1          0.5         1   5       1          43
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
def nomallize(df):
    decrease_1000=['battery_power','px_height','px_width','ram']
    decrease_100=['mobile_wt','int_memory']
    decrease_10=['sc_h','sc_w','talk_time','n_cores','fc']
    for key in decrease_1000:
        df[key]=df[key]/1000
    for key in decrease_100:
        df[key]=df[key]/100
    for key in decrease_10:
        df[key]=df[key]/10

# %%
def nomallize_corr(df,corr):
    i=0
    keys=list(df.keys())
    keys.pop()
    print(keys)
    for key in keys:
        df[key]=df[key]*corr[i]
        i+=1

# %%
df_train.keys()
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
cor = correlation(X_train,Y_train)

# %%
cor
# Out:
# array([ 0.18903833,  0.02871585, -0.00849849,  0.02670289,  0.02508987,
#         0.02249368,  0.0517983 , -0.00312229, -0.03108667,  0.00621786,
#         0.03638936,  0.13454539,  0.15303343,  0.91895849,  0.02565342,
#         0.04195442,  0.02449601,  0.03705732, -0.02626952,  0.02070309])

# %%
nomallize(df=df_train)
# nomallize_corr(df=df_train,corr=cor)

# %%
df_train
# Out:
#       battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  \
# id
# 1             0.842     0          2.2         0  0.1       0        0.07
# 2             1.021     1          0.5         1  0.0       1        0.53
# 3             0.563     1          0.5         1  0.2       1        0.41
# 4             0.615     1          2.5         0  0.0       0        0.10
# 5             1.821     1          1.2         0  1.3       1        0.44
# ...             ...   ...          ...       ...  ...     ...         ...
# 1496          1.472     0          3.0         0  0.4       1        0.20
# 1497          1.868     1          0.5         0  0.2       1        0.40
# 1498          1.375     0          2.9         0  0.2       0        0.20
# 1499          0.881     0          1.0         0  0.1       0        0.64
# 1500          1.742     1          0.5         1  0.5       1        0.43
#
# ...

# %%
X_train = df_train.iloc[:, :-1]
Y_train = df_train.iloc[:, -1]
Y_train = np.array(Y_train)
X_train = np.array(X_train)
# X=X/100
# Y=Y/100

# %%
X_train.shape
# Out:
# (1500, 20)

# %%
Y_train.shape
# Out:
# (1500,)

# %%
import numpy as np

def correlation(X, y):
    n_samples, n_features = X.shape

    # Compute the mean of X and y
    X_mean = np.mean(X, axis=0)
    y_mean = np.mean(y)

    # Compute the covariance matrix
    cov_mat = np.zeros((n_features, n_features))
    for i in range(n_features):
        for j in range(n_features):
            cov_mat[i, j] = np.sum((X[:, i] - X_mean[i]) * (X[:, j] - X_mean[j])) / (n_samples - 1)

    # Compute the correlation matrix
    corr_mat = np.zeros((n_features,))
    for i in range(n_features):
        corr_mat[i] = np.sum((X[:, i] - X_mean[i]) * (y - y_mean)) / np.sqrt(np.sum((X[:, i] - X_mean[i])**2) * np.sum((y - y_mean)**2))
    return corr_mat

class LinearRegression:
    def __init__(self, learning_rate=0.001):
        self.learning_rate = learning_rate
        self.weights = None
        self.bias = None
        self.loss_history = []

    def fit(self, X, y):
        # Initialize the parameters
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Perform gradient descent
        mse = 1
        while round(mse,5)>0.10093:
            y_predicted = np.dot(X,self.weights) + self.bias
            dw = (1/n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1/n_samples) * np.sum(y_predicted - y)
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db
            mse = np.mean((y_predicted - y)**2)
            print(mse)
            self.loss_history.append(mse)
    def predict(self, X):
        y_predicted = np.dot(X, self.weights) + self.bias
        return y_predicted

# %%
model = LinearRegression(learning_rate=0.0025)

# %%
model = LinearRegression(learning_rate=0.005)

# %%
cor
# Out:
# array([ 0.18903833,  0.02871585, -0.00849849,  0.02670289,  0.02508987,
#         0.02249368,  0.0517983 , -0.00312229, -0.03108667,  0.00621786,
#         0.03638936,  0.13454539,  0.15303343,  0.91895849,  0.02565342,
#         0.04195442,  0.02449601,  0.03705732, -0.02626952,  0.02070309])

# %%
model.fit(X_train, Y_train)
# Out:
# 3.5193333333333334
# 1.7399894454239009
# 1.5805637494456715
# 1.528675678612007
# 1.4856581059494243
# 1.444989067042777
# 1.4061568128652198
# 1.3690456394134198
# 1.3335697614622413
# 1.2996492443670176
# 1.2672082401788045
# 1.2361746872456676
# 1.2064801144857733
# 1.1780594613047968
# 1.1508509069132609
# 1.1247957082170341
# 1.099838045828343
# 1.0759248777890198
# 1.053005800619563
# 1.0310329173270487
# 1.009960712023303
# 0.9897459308222321
# 0.970347468701763
# 0.9517262620316354
# 0.9338451864832226
# 0.9166689600518027
# 0.9001640509351824
# 0.884298590025424
# 0.8690422877825974
# 0.8543663552710606
# 0.8402434291497695
# 0.8266475004185544
# 0.8135538467322311
# 0.800938968103834
# 0.7887805258272085
# 0.77705728445771
# 0.7657490566978323
# 0.7548366510422552
# 0.7443018220441009
# 0.7341272230711046
# 0.7242963614269815
# 0.7147935557195255
# 0.7056038953629035
# 0.6967132021072487
# 0.6881079934940129
# 0.6797754481406175
# 0.6717033727627869
# 0.6638801708475215
# ...

# %%
round(0.10093241046470557,5)
# Out:
# 0.10093

# %%
model.loss_history[-1]
# Out:
# 0.10093499992020918

# %%
min(model.loss_history)
# Out:
# 0.10499995591334198

# %%
plt.plot(model.loss_history)

# %%
model.weights
# Out:
# array([ 4.98176432e-01, -1.50563596e-03, -1.40608564e-02, -1.58491916e-02,
#         1.01929263e-03, -9.10715226e-03,  5.67149605e-02, -2.16077508e-02,
#        -8.70223332e-02, -1.41736321e-05,  6.30516733e-05,  2.84237155e-01,
#         2.75426958e-01,  9.44104710e-01,  7.82771760e-03, -9.12361314e-03,
#        -4.35504475e-03,  4.00099189e-02, -9.74048520e-03, -1.46334073e-02])

# %%
model.bias
# Out:
# -1.523076727283449

# %%
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 model.predict()
#
# TypeError: LinearRegression.predict() missing 1 required positional argument: 'X'

# %%
df_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# id
# 1             0.842     0          2.2         0   1       0        0.07
# 2             1.021     1          0.5         1   0       1        0.53
# 3             0.563     1          0.5         1   2       1        0.41
# 4             0.615     1          2.5         0   0       0        0.10
# 5             1.821     1          1.2         0  13       1        0.44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1496          1.472     0          3.0         0   4       1        0.20
# 1497          1.868     1          0.5         0   2       1        0.40
# 1498          1.375     0          2.9         0   2       0        0.20
# 1499          0.881     0          1.0         0   1       0        0.64
# 1500          1.742     1          0.5         1   5       1        0.43
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width    ram  sc_h  sc_w  \
# ...

# %%
round(model.predict(X_train[2]))
# Out:
# 2

# %%
# Create the linear regression model

# Train the model
# cor = correlation(X,y)

# plt.plot(model.loss_history)
y_pred = model.predict(X_train)
y_pred = np.around(y_pred)
y_pred
# Out:
# array([1., 2., 2., ..., 3., 1., 2.])

# %%
df_val = pd.read_csv('data/val.csv',index_col = 0)
nomallize(df=df_val)
X_val = df_val.iloc[:, :-1]
Y_val = df_val.iloc[:, -1]
Y_val = np.array(Y_val)
X_val = np.array(X_val)

# %%
y_pred = model.predict(X_val)
mse = np.mean((y_pred - Y_val)**2)
print('Mean squared error:', mse)
# Out:
# Mean squared error: 0.10483111787756659

# %%
df_test = pd.read_csv('data/test.csv',index_col = 0)
nomallize(df=df_test)
X_test = df_val.iloc[:, :]
X_test = np.array(X_test)

# %%
X_test.shape
# Out:
# (1000, 20)

# %%
y_pred = model.predict(X_test)
y_pred = abs(np.around(y_pred))
y_pred
# Out:
# array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 1., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 1., 2., 2.,
#        2., 2., 2., 2., 2., 1., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
# ...

# %%
df_test['range_price']=y_pred

# %%
df_test.to_csv('Result_Test.csv')
